# %% [markdown]
# # Sales Recruitment Dataset — Initial Exploration
#
# MBA AI and Analytics in Business Practice — in-class project.
#
# This notebook loads the recruitment dataset and takes a first look at it:
#
# 1. Import `pandas`
# 2. Read the CSV file
# 3. Display the first five rows
# 4. Display summary statistics

# %% [markdown]
# ## 1. Import libraries

# %%
import pandas as pd

# %% [markdown]
# ## 2. Read the dataset
#
# The dataset lives in the repository root as `sales_recruitment_synthetic_200.csv`.

# %%
df = pd.read_csv("sales_recruitment_synthetic_200.csv")

print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")

# %% [markdown]
# ## 3. First five rows
#
# A quick sanity check that the columns parsed correctly.

# %%
df.head()

# %% [markdown]
# ## 4. Summary statistics
#
# `describe()` on its own covers only the numeric columns. Passing
# `include="all"` adds the categorical ones (count, unique, top, freq) so the
# whole dataset is summarised in one table.

# %%
df.describe()

# %%
df.describe(include="all")
